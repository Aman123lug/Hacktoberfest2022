# %% [markdown]
# <a href="https://colab.research.google.com/github/Adhiraj-11/ML-Projects-1/blob/main/fahsion_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **IMPORTING LIBRARIES**

# %%
import tensorflow as tf
from tensorflow import keras 
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# **fashion dataset from keras**

# %%
fashion_mnist = keras.datasets.fashion_mnist
(train_images, train_labels),(test_images,test_labels) = fashion_mnist.load_data()

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
train_images[0,23,23]
# Out:
# 194

# %%
class_names = ['T-shirt/top','Trouser','Pullover','Dress','Coat',
               'Sandal','Shirt','Sneaker','Bag','Ankle Boot']

# %%
plt.figure()
plt.imshow(train_images[1])
plt.colorbar()
plt.show()

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(128,activation='relu'),
    keras.layers.Dense(10,activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# training the model

# %%
model.fit(train_images, train_labels, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4941 - accuracy: 0.8255
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3782 - accuracy: 0.8633
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3377 - accuracy: 0.8772
# Epoch 4/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3120 - accuracy: 0.8858
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2951 - accuracy: 0.8913
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2785 - accuracy: 0.8966
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2679 - accuracy: 0.9018
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2572 - accuracy: 0.9036
# Epoch 9/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2500 - accuracy: 0.9075
# Epoch 10/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2404 - accuracy: 0.9105

# %%
train_loss, test_acc = model.evaluate(test_images, test_labels, verbose=1)

print('Test accuracy: ', test_acc)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3290 - accuracy: 0.8850
# Test accuracy:  0.8849999904632568

# %% [markdown]
# ***Prediction***

# %%
prediction = model.predict(test_images)
print(class_names[np.argmax(prediction[400])])
# Out:
# T-shirt/top

# %%
plt.figure()
plt.imshow(train_images[400])
plt.colorbar()
plt.show()
