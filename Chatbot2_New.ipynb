# %%
import nltk
nltk.download('omw-1.4')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
import random
words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('intents.json').read()
intents = json.loads(data_file)
# Out:
# [nltk_data] Downloading package omw-1.4 to C:\Users\tirthadagr8
# [nltk_data]     ghosh\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
for intent in intents['intents']:
    for pattern in intent['patterns']:
#tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
#add documents in the corpus
        documents.append((w, intent['tag']))
# add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %%
# lemmatize, lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# 47 documents
# 9 classes ['adverse_drug', 'blood_pressure', 'blood_pressure_search', 'goodbye', 'greeting', 'hospital_search', 'options', 'pharmacy_search', 'thanks']
# 88 unique lemmatized words ["'s", ',', 'a', 'adverse', 'all', 'anyone', 'are', 'awesome', 'be', 'behavior', 'blood', 'by', 'bye', 'can', 'causing', 'chatting', 'check', 'could', 'data', 'day', 'detail', 'do', 'dont', 'drug', 'entry', 'find', 'for', 'give', 'good', 'goodbye', 'have', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'history', 'hola', 'hospital', 'how', 'i', 'id', 'is', 'later', 'list', 'load', 'locate', 'log', 'looking', 'lookup', 'management', 'me', 'module', 'nearby', 'next', 'nice', 'of', 'offered', 'open', 'patient', 'pharmacy', 'pressure', 'provide', 'reaction', 'related', 'result', 'search', 'searching', 'see', 'show', 'suitable', 'support', 'task', 'thank', 'thanks', 'that', 'there', 'till', 'time', 'to', 'transfer', 'up', 'want', 'what', 'which', 'with', 'you']

# %%
# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
# initialize our bag of words
    bag = []
# list of tokenized words for the pattern
    pattern_words = doc[0]
# lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
# create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
# output is a '0' for each tag and '1' for current tag (for each pattern)
output_row = list(output_empty)
output_row[classes.index(doc[1])] = 1
training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")
# Out:
# Training data created
# <ipython-input-71-98bf8d2847b6>:22: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   training = np.array(training)

# %%
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))
# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
#fitting and saving the model
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)
print("model created")
# Out:
# Epoch 1/200
# 1/1 [==============================] - 1s 899ms/step - loss: 2.3701 - accuracy: 0.0000e+00
# Epoch 2/200
# 1/1 [==============================] - 0s 7ms/step - loss: 2.2116 - accuracy: 0.0000e+00
# Epoch 3/200
# 1/1 [==============================] - 0s 6ms/step - loss: 2.2082 - accuracy: 0.0000e+00
# Epoch 4/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.8652 - accuracy: 1.0000
# Epoch 5/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.6903 - accuracy: 1.0000
# Epoch 6/200
# 1/1 [==============================] - 0s 6ms/step - loss: 1.6835 - accuracy: 1.0000
# Epoch 7/200
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1989 - accuracy: 1.0000
# Epoch 8/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0897 - accuracy: 1.0000
# Epoch 9/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7340 - accuracy: 1.0000
# Epoch 10/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2398 - accuracy: 1.0000
# Epoch 11/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0494 - accuracy: 1.0000
# Epoch 12/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.3663 - accuracy: 1.0000
# Epoch 13/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0562 - accuracy: 1.0000
# Epoch 14/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3513 - accuracy: 1.0000
# Epoch 15/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0685 - accuracy: 1.0000
# Epoch 16/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 17/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 18/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 19/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0207 - accuracy: 1.0000
# Epoch 20/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 21/200
# 1/1 [==============================] - 0s 8ms/step - loss: 4.0531e-06 - accuracy: 1.0000
# Epoch 22/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 23/200
# 1/1 [==============================] - 0s 9ms/step - loss: 4.9555e-04 - accuracy: 1.0000
# Epoch 24/200
# 1/1 [==============================] - 0s 10ms/step - loss: 7.1526e-07 - accuracy: 1.0000
# Epoch 25/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 26/200
# 1/1 [==============================] - 0s 6ms/step - loss: 5.4836e-06 - accuracy: 1.0000
# Epoch 27/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.5497e-06 - accuracy: 1.0000
# Epoch 28/200
# 1/1 [==============================] - 0s 8ms/step - loss: 5.7359e-04 - accuracy: 1.0000
# Epoch 29/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0167 - accuracy: 1.0000
# Epoch 30/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2007 - accuracy: 1.0000
# Epoch 31/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 32/200
# 1/1 [==============================] - 0s 8ms/step - loss: 5.9605e-07 - accuracy: 1.0000
# Epoch 33/200
# 1/1 [==============================] - 0s 7ms/step - loss: 2.3577e-04 - accuracy: 1.0000
# Epoch 34/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 35/200
# 1/1 [==============================] - 0s 9ms/step - loss: 3.5041e-04 - accuracy: 1.0000
# Epoch 36/200
# 1/1 [==============================] - 0s 6ms/step - loss: 6.2702e-05 - accuracy: 1.0000
# Epoch 37/200
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8781e-05 - accuracy: 1.0000
# Epoch 38/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 39/200
# 1/1 [==============================] - 0s 8ms/step - loss: 8.0339e-04 - accuracy: 1.0000
# Epoch 40/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1348e-04 - accuracy: 1.0000
# Epoch 41/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 42/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0535 - accuracy: 1.0000
# Epoch 43/200
# 1/1 [==============================] - 0s 7ms/step - loss: 3.6358e-05 - accuracy: 1.0000
# Epoch 44/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 45/200
# 1/1 [==============================] - 0s 7ms/step - loss: 9.8939e-05 - accuracy: 1.0000
# Epoch 46/200
# 1/1 [==============================] - 0s 8ms/step - loss: 6.6757e-06 - accuracy: 1.0000
# Epoch 47/200
# 1/1 [==============================] - 0s 7ms/step - loss: 5.9604e-06 - accuracy: 1.0000
# Epoch 48/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 49/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 50/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.0266e-06 - accuracy: 1.0000
# Epoch 51/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.8118e-04 - accuracy: 1.0000
# Epoch 52/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 53/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0773 - accuracy: 1.0000
# Epoch 54/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.2898e-04 - accuracy: 1.0000
# Epoch 55/200
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1921e-07 - accuracy: 1.0000
# Epoch 56/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 57/200
# 1/1 [==============================] - 0s 8ms/step - loss: 7.8516e-04 - accuracy: 1.0000
# Epoch 58/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1921e-07 - accuracy: 1.0000
# Epoch 59/200
# 1/1 [==============================] - 0s 7ms/step - loss: 5.2452e-06 - accuracy: 1.0000
# Epoch 60/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.5497e-05 - accuracy: 1.0000
# Epoch 61/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 62/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 63/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 64/200
# 1/1 [==============================] - 0s 9ms/step - loss: 2.8610e-06 - accuracy: 1.0000
# Epoch 65/200
# 1/1 [==============================] - 0s 6ms/step - loss: 4.2915e-06 - accuracy: 1.0000
# Epoch 66/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 67/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 68/200
# 1/1 [==============================] - 0s 10ms/step - loss: 9.0237e-05 - accuracy: 1.0000
# Epoch 69/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1157e-04 - accuracy: 1.0000
# Epoch 70/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1921e-07 - accuracy: 1.0000
# Epoch 71/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 72/200
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2147e-04 - accuracy: 1.0000
# Epoch 73/200
# 1/1 [==============================] - 0s 10ms/step - loss: 9.4648e-05 - accuracy: 1.0000
# Epoch 74/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.4305e-06 - accuracy: 1.0000
# Epoch 75/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0554 - accuracy: 1.0000
# Epoch 76/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 77/200
# 1/1 [==============================] - 0s 8ms/step - loss: 5.2452e-06 - accuracy: 1.0000
# Epoch 78/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.2886e-04 - accuracy: 1.0000
# Epoch 79/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.3434e-04 - accuracy: 1.0000
# Epoch 80/200
# 1/1 [==============================] - 0s 8ms/step - loss: 6.3459e-04 - accuracy: 1.0000
# Epoch 81/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1109 - accuracy: 1.0000
# Epoch 82/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2731e-04 - accuracy: 1.0000
# Epoch 83/200
# 1/1 [==============================] - 0s 9ms/step - loss: 5.9605e-07 - accuracy: 1.0000
# Epoch 84/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1564 - accuracy: 1.0000
# Epoch 85/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 86/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 87/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 88/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1921e-07 - accuracy: 1.0000
# Epoch 89/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1373 - accuracy: 1.0000
# Epoch 90/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 91/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 92/200
# 1/1 [==============================] - 0s 7ms/step - loss: 9.1523e-04 - accuracy: 1.0000
# Epoch 93/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.6689e-06 - accuracy: 1.0000
# Epoch 94/200
# 1/1 [==============================] - 0s 7ms/step - loss: 2.8848e-05 - accuracy: 1.0000
# Epoch 95/200
# 1/1 [==============================] - 0s 9ms/step - loss: 9.0599e-06 - accuracy: 1.0000
# Epoch 96/200
# 1/1 [==============================] - 0s 7ms/step - loss: 2.1696e-05 - accuracy: 1.0000
# Epoch 97/200
# 1/1 [==============================] - 0s 11ms/step - loss: 2.4080e-05 - accuracy: 1.0000
# Epoch 98/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0729e-06 - accuracy: 1.0000
# Epoch 99/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 100/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1539e-04 - accuracy: 1.0000
# Epoch 101/200
# 1/1 [==============================] - 0s 10ms/step - loss: 6.4373e-06 - accuracy: 1.0000
# Epoch 102/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 103/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.8358e-05 - accuracy: 1.0000
# Epoch 104/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 105/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1921e-07 - accuracy: 1.0000
# Epoch 106/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 107/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 108/200
# 1/1 [==============================] - 0s 9ms/step - loss: 4.1723e-06 - accuracy: 1.0000
# Epoch 109/200
# 1/1 [==============================] - 0s 8ms/step - loss: 4.7684e-07 - accuracy: 1.0000
# Epoch 110/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 111/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0729e-06 - accuracy: 1.0000
# Epoch 112/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1921e-07 - accuracy: 1.0000
# Epoch 113/200
# 1/1 [==============================] - 0s 9ms/step - loss: 4.7684e-07 - accuracy: 1.0000
# Epoch 114/200
# 1/1 [==============================] - 0s 10ms/step - loss: 5.9605e-07 - accuracy: 1.0000
# Epoch 115/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 116/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1921e-06 - accuracy: 1.0000
# Epoch 117/200
# 1/1 [==============================] - 0s 7ms/step - loss: 2.3842e-07 - accuracy: 1.0000
# Epoch 118/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 119/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 120/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 121/200
# 1/1 [==============================] - 0s 7ms/step - loss: 4.6610e-05 - accuracy: 1.0000
# Epoch 122/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.3365e-05 - accuracy: 1.0000
# Epoch 123/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 124/200
# 1/1 [==============================] - 0s 8ms/step - loss: 7.3909e-06 - accuracy: 1.0000
# Epoch 125/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 126/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.9073e-06 - accuracy: 1.0000
# Epoch 127/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0729e-06 - accuracy: 1.0000
# Epoch 128/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1921e-07 - accuracy: 1.0000
# Epoch 129/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 130/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 131/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 132/200
# 1/1 [==============================] - 0s 7ms/step - loss: 6.1989e-06 - accuracy: 1.0000
# Epoch 133/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0275 - accuracy: 1.0000
# Epoch 134/200
# 1/1 [==============================] - 0s 10ms/step - loss: 4.7325e-05 - accuracy: 1.0000
# Epoch 135/200
# 1/1 [==============================] - 0s 10ms/step - loss: 8.3446e-06 - accuracy: 1.0000
# Epoch 136/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 137/200
# 1/1 [==============================] - 0s 10ms/step - loss: 3.1991e-04 - accuracy: 1.0000
# Epoch 138/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 139/200
# 1/1 [==============================] - 0s 9ms/step - loss: 3.0040e-05 - accuracy: 1.0000
# Epoch 140/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 141/200
# 1/1 [==============================] - 0s 7ms/step - loss: 2.3842e-07 - accuracy: 1.0000
# Epoch 142/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 143/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 144/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 145/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 146/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 147/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 148/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1921e-07 - accuracy: 1.0000
# Epoch 149/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1551e-04 - accuracy: 1.0000
# Epoch 150/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0811 - accuracy: 1.0000
# Epoch 151/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 152/200
# 1/1 [==============================] - 0s 10ms/step - loss: 7.1526e-07 - accuracy: 1.0000
# Epoch 153/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.3828e-05 - accuracy: 1.0000
# Epoch 154/200
# 1/1 [==============================] - 0s 9ms/step - loss: 2.1815e-05 - accuracy: 1.0000
# Epoch 155/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 156/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 157/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.6093e-05 - accuracy: 1.0000
# Epoch 158/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 159/200
# 1/1 [==============================] - 0s 6ms/step - loss: 8.3446e-07 - accuracy: 1.0000
# Epoch 160/200
# 1/1 [==============================] - 0s 7ms/step - loss: 5.9605e-07 - accuracy: 1.0000
# Epoch 161/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 162/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 163/200
# 1/1 [==============================] - 0s 8ms/step - loss: 4.7684e-07 - accuracy: 1.0000
# Epoch 164/200
# 1/1 [==============================] - 0s 7ms/step - loss: 4.7684e-07 - accuracy: 1.0000
# Epoch 165/200
# 1/1 [==============================] - 0s 9ms/step - loss: 8.3446e-07 - accuracy: 1.0000
# Epoch 166/200
# 1/1 [==============================] - 0s 9ms/step - loss: 9.8133e-04 - accuracy: 1.0000
# Epoch 167/200
# 1/1 [==============================] - 0s 11ms/step - loss: 3.2186e-06 - accuracy: 1.0000
# Epoch 168/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 169/200
# 1/1 [==============================] - 0s 8ms/step - loss: 8.3446e-07 - accuracy: 1.0000
# Epoch 170/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 171/200
# 1/1 [==============================] - 0s 10ms/step - loss: 2.3842e-07 - accuracy: 1.0000
# Epoch 172/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.8610e-06 - accuracy: 1.0000
# Epoch 173/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 174/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 175/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 176/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 177/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 178/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.9774e-04 - accuracy: 1.0000
# Epoch 179/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1014 - accuracy: 1.0000
# Epoch 180/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 181/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.4983e-04 - accuracy: 1.0000
# Epoch 182/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.5378e-05 - accuracy: 1.0000
# Epoch 183/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3389 - accuracy: 1.0000
# Epoch 184/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 185/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 186/200
# 1/1 [==============================] - 0s 10ms/step - loss: 2.3842e-07 - accuracy: 1.0000
# Epoch 187/200
# 1/1 [==============================] - 0s 10ms/step - loss: 2.0121e-04 - accuracy: 1.0000
# Epoch 188/200
# 1/1 [==============================] - 0s 9ms/step - loss: 3.9165e-04 - accuracy: 1.0000
# Epoch 189/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 190/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1921e-07 - accuracy: 1.0000
# Epoch 191/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 192/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 193/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 194/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0967e-05 - accuracy: 1.0000
# Epoch 195/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.2650e-06 - accuracy: 1.0000
# Epoch 196/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 197/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 198/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.3842e-07 - accuracy: 1.0000
# Epoch 199/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 200/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# model created

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import pickle
import numpy as np
from keras.models import load_model
model = load_model('chatbot_model.h5')
import json
import random
intents = json.loads(open('intents.json').read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))

# %%
def clean_up_sentence(sentence):
# tokenize the pattern - split words into array
    sentence_words = nltk.word_tokenize(sentence)
# stem each word - create short form for word
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words
# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence
def bow(sentence, words, show_details=True):
# tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
# bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words)
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s:
# assign 1 if current word is in the vocabulary position
                bag[i] = 1
            if show_details:
                print ("found in bag: %s" % w)
    return(np.array(bag))
def predict_class(sentence, model):
# filter out predictions below a threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
# sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

# %%
def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result
def chatbot_response(text):
    ints = predict_class(text, model)
    res = getResponse(ints, intents)
    return res

# %%
import tkinter
tkinter._test()

# %%
#Creating GUI with tkinter
import tkinter 
from tkinter import*

def send():
    msg = EntryBox.get("1.0",'end-1c').strip()
    EntryBox.delete("0.0",END)
    if msg != '':
        ChatLog.config(state=NORMAL)
        ChatLog.insert(END, "You: " + msg + '\n\n')
        ChatLog.config(foreground="#442265", font=("Verdana", 12 ))
        res = chatbot_response(msg)
        ChatLog.insert(END, "Bot: " + res + '\n\n')
        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)
    
    
base = Tk()
base.title("Hello")
base.geometry("400x500")
base.resizable(width=FALSE, height=FALSE)
#Create Chat window
ChatLog = Text(base, bd=0, bg="white", height="8", width="50", font="Arial",)
ChatLog.config(state=DISABLED)
#Bind scrollbar to Chat window
scrollbar = Scrollbar(base, command=ChatLog.yview, cursor="heart")
ChatLog['yscrollcommand'] = scrollbar.set
#Create Button to send message
SendButton = Button(base, font=("Verdana",12,'bold'), text="Send", width="12", height=5,
bd=0, bg="#32de97", activebackground="#3c9d9b",fg='#ffffff',
command= send )
#Create the box to enter message
EntryBox = Text(base, bd=0, bg="white",width="29", height="5", font="Arial")
#EntryBox.bind("<Return>", send)
#Place all components on the screen
scrollbar.place(x=376,y=6, height=386)
ChatLog.place(x=6,y=6, height=386, width=370)
EntryBox.place(x=128, y=401, height=90, width=265)
SendButton.place(x=6, y=401, height=90)
base.mainloop()
